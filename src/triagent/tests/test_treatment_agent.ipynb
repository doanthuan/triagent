# %%
import sys
sys.path.append('../../')


from triagent.agents.therapy.services.trial.service import TrialService


DISEASE = "glioblastoma"

# Load the patient summary
def read_patient_summary(file_path: str):
    """Read patient summary from the specified markdown file."""
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        print(f"Patient summary file not found: {file_path}")
        return "Patient summary not available."
    except Exception as e:
        print(f"Error reading patient summary: {str(e)}")
        return "Error reading patient summary."

patient_info = read_patient_summary("cases/11 - astrocytoma-case-summary.md")

trial_service = TrialService()
trials = await trial_service.search_clinical_trials(patient_info)
print("Number of trials found: ", len(trials))

# patient_data = await trial_service._parse_patient_data_from_string(patient_info)
# case_26_query = """
# ("Glioblastoma" OR "GBM") AND ("WHO grade 4" OR "grade 4" OR "grade IV") AND ("IDH-wildtype" OR "IDH wildtype" OR "IDH wild-type" OR "IDHwt" OR "IDH WT")
# """
# trials = await trial_service._search_clinical_trials_with_query(case_26_query)
# print(len(trials))
# eligible_trials = await trial_service.match_trials_to_patient(trials, patient_data)
# print(len(eligible_trials))
# Out:
# 2025-06-18 18:55:33.259 | INFO     | triagent.agents.treatment.services.trial.service:_parse_patient_data_from_string:37 | Patient data extraction response: {
#   "biomarkers": [
#     "ATRX D1940Ifs*15",
#     "IDH1 R132H",
#     "TP53 P250L",
#     "EGFR Amplification",
#     "PDGFRA Amplification",
#     "PTEN Deletion",
#     "MYCN Amplification by FISH (Equivocal)",
#     "Microsatellite Instability (MSI-Stable)",
#     "Tumor Mutation Burden (Low)",
#     "EGFRvIII (Not Detected)",
#     "MGMT Promoter Methylation (Not Detected)",
#     "PD-L1 (Negative/Not Detected)"
#   ],
#   "histology": "Astrocytoma Grade 4",
#   "staging": "",
#   "ecog_performance_status": "",
#   "first_line_treatment": "Surgery, Radiation with Temozolomide (TMZ), Chemotherapy (TMZ)",
#   "second_line_treatment": "Stereotactic radiation, Lomustine (discontinued), Carboplatin (discontinued), Avastin (bevacizumab) monotherapy",
#   "age": "37"
# }
# 2025-06-18 18:55:33.260 | INFO     | triagent.agents.treatment.services.trial.service:_parse_patient_data_from_string:39 | Parsed patient data: {'biomarkers': ['ATRX D1940Ifs*15', 'IDH1 R132H', 'TP53 P250L', 'EGFR Amplification', 'PDGFRA Amplification', 'PTEN Deletion', 'MYCN Amplification by FISH (Equivocal)', 'Microsatellite Instability (MSI-Stable)', 'Tumor Mutation Burden (Low)', 'EGFRvIII (Not Detected)', 'MGMT Promoter Methylation (Not Detected)', 'PD-L1 (Negative/Not Detected)'], 'histology': 'Astrocytoma Grade 4', 'staging': '', 'ecog_performance_status': '', 'first_line_treatment': 'Surgery, Radiation with Temozolomide (TMZ), Chemotherapy (TMZ)', 'second_line_treatment': 'Stereotactic radiation, Lomustine (discontinued), Carboplatin (discontinued), Avastin (bevacizumab) monotherapy', 'age': '37'}
# 2025-06-18 18:55:33.260 | INFO     | triagent.agents.treatment.services.trial.service:search_clinical_trials:163 | Parsed patient data: biomarkers=['ATRX D1940Ifs*15', 'IDH1 R132H', 'TP53 P250L', 'EGFR Amplification', 'PDGFRA Amplification', 'PTEN Deletion', 'MYCN Amplification by FISH (Equivocal)', 'Microsatellite Instability (MSI-Stable)', 'Tumor Mutation Burden (Low)', 'EGFRvIII (Not Detected)', 'MGMT Promoter Methylation (Not Detected)', 'PD-L1 (Negative/Not Detected)'] histology='Astrocytoma Grade 4' staging='' ecog_performance_status='' first_line_treatment='Surgery, Radiation with Temozolomide (TMZ), Chemotherapy (TMZ)' second_line_treatment='Stereotactic radiation, Lomustine (discontinued), Carboplatin (discontinued), Avastin (bevacizumab) monotherapy' age='37'
# 2025-06-18 18:55:34.778 | INFO     | triagent.agents.treatment.services.trial.service:search_clinical_trials:167 | Generated clinical trial search criteria: ("astrocytoma grade 4" OR "glioblastoma" OR "grade IV astrocytoma") AND (ATRX OR IDH1 OR TP53 OR EGFR OR PDGFRA OR PTEN OR MYCN)
# 2025-06-18 18:55:35.516 | INFO     | triagent.agents.treatment.services.trial.service:search_clinical_trials:171 | Clinical trials found: 24
# Number of trials found:  24

# %%
# Test rerank service

import sys
sys.path.append('../../')

from triagent.agents.therapy.services.rerank.service import TourRankService

rerank_service = TourRankService()

results = await rerank_service.rerank_trials(patient_info, trials)
print(results[1])
# Out:
# 2025-06-18 18:55:35.561 | INFO     | triagent.agents.treatment.services.rerank.service:rerank_trials:155 | Ranking trials for patient: # Patient Summary
#
# **Patient**: Not specified
# **Age**: 37
# **Sex**: Female
# **Date of Diagnosis**: December 2022
# **Primary Cancer Type**: Astrocytoma Grade 4
# **Medical Diagnosis**: Grade 4 Astrocytoma with recurrence
# **Current Treatment Status**: Disease progression with multiple tumors; currently on Avastin only
#
# ## Treatment History
#
# **Treatments**:
# - Surgery, Radiation, Chemotherapy, Targeted Therapy
#
# **Specific Interventions**:
# - 12/09/2022: Surgery (100% resection)
# - 01/2023: Completed radiation with Temozolomide (TMZ)
# - 01/2023-01/2024: Completed 12 months of TMZ
# - 03/2024: Stereotactic radiation at Duke for recurrent tumors
# - Recent: Discontinued Lomustine after unspecified duration
# - Recent: Discontinued Carboplatin after single treatment
# - Current: Avastin (bevacizumab) monotherapy
#
# ## Molecular/Genetic Characteristics
#
# **Biomarkers**:
# - ATRX D1940Ifs*15
# - IDH1 R132H
# - TP53 P250L
# - EGFR Amplification: AMPLIFIED
# - PDGFRA Amplification: POSITIVE
# - PTEN Deletion: POSITIVE
# - MYCN Amplification by FISH: Equivocal
# - Microsatellite Instability: MSI-Stable (MSS)
# - Tumor Mutation Burden: Low
# - EGFRvIII: Not Detected
# - MGMT Promoter Methylation: Not Detected
# - PD-L1: Negative/Not Detected
#
# ## Additional Information
#
# **Oncology History**: Duke University Medical Center (radiation treatment)
# **Access to records**: Yes
#
# ## Clinical Status
#
# **Current Symptoms**:
# - Severe headaches
# - Extremity numbness
# - Elevated liver enzymes
# - Intermittent facial agnosia
# - Left-sided vision cut
# - No current seizures
#
# ## Clinical Questions
#
# 1. Are there updated clinical trials available for recurrent Grade 4 Astrocytoma?
# 2. Are there alternative chemotherapy options for this case?
# 2025-06-18 18:55:35.561 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:123 | Start group ranking for stage 1 with 24 trials and 6 groups
# 2025-06-18 18:55:35.562 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.562 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.562 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.563 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.564 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.565 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:35.565 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:35.566 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:35.566 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:35.567 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:35.568 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:35.569 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:36.420 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT05168423', 'NCT02861898']
# 2025-06-18 18:55:36.447 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT04547777', 'NCT02800486']
# 2025-06-18 18:55:36.532 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT06072586', 'NCT06047379']
# 2025-06-18 18:55:36.635 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT03896568', 'NCT05432518']
# 2025-06-18 18:55:36.699 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT04590664', 'NCT02704858']
# 2025-06-18 18:55:37.233 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT06934889', 'NCT06161974']
# 2025-06-18 18:55:37.235 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:123 | Start group ranking for stage 2 with 12 trials and 3 groups
# 2025-06-18 18:55:37.235 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:37.235 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:37.236 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 4 trials and top_m=2
# 2025-06-18 18:55:37.236 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:37.237 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:37.239 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 4 trials
# 2025-06-18 18:55:38.083 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT05168423', 'NCT02704858']
# 2025-06-18 18:55:38.182 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT06072586', 'NCT06934889']
# 2025-06-18 18:55:38.311 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT04590664', 'NCT04547777']
# 2025-06-18 18:55:38.312 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:123 | Start group ranking for stage 3 with 6 trials and 2 groups
# 2025-06-18 18:55:38.312 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 3 trials and top_m=1
# 2025-06-18 18:55:38.313 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 3 trials and top_m=1
# 2025-06-18 18:55:38.313 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 3 trials
# 2025-06-18 18:55:38.314 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 3 trials
# 2025-06-18 18:55:38.926 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT04590664']
# 2025-06-18 18:55:39.143 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT02704858']
# 2025-06-18 18:55:39.144 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:123 | Start group ranking for stage 4 with 2 trials and 1 groups
# 2025-06-18 18:55:39.145 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:127 | Group ranking with 2 trials and top_m=1
# 2025-06-18 18:55:39.145 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:61 | Group ranking with 2 trials
# 2025-06-18 18:55:40.293 | INFO     | triagent.agents.treatment.services.rerank.service:group_ranking:91 | Top trial NCT IDs: ['NCT04590664']
# 2025-06-18 18:55:40.294 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:149 | Finished tournament 1.
# 2025-06-18 18:55:40.294 | INFO     | triagent.agents.treatment.services.rerank.service:tournament_ranking:150 | Tournament 1 scores: {'NCT06934889': 2, 'NCT03749187': 0, 'NCT06186401': 0, 'NCT05432518': 1, 'NCT04197934': 0, 'NCT06047379': 1, 'NCT03175224': 0, 'NCT02861898': 1, 'NCT04931732': 0, 'NCT06059690': 0, 'NCT02704858': 3, 'NCT06327451': 0, 'NCT05052957': 0, 'NCT05313191': 0, 'NCT04547777': 2, 'NCT03919292': 0, 'NCT06894979': 0, 'NCT05256290': 0, 'NCT06161974': 1, 'NCT05168423': 2, 'NCT02800486': 1, 'NCT03896568': 1, 'NCT04590664': 4, 'NCT06072586': 2}
# {'NCT06934889': 2, 'NCT03749187': 0, 'NCT06186401': 0, 'NCT05432518': 1, 'NCT04197934': 0, 'NCT06047379': 1, 'NCT03175224': 0, 'NCT02861898': 1, 'NCT04931732': 0, 'NCT06059690': 0, 'NCT02704858': 3, 'NCT06327451': 0, 'NCT05052957': 0, 'NCT05313191': 0, 'NCT04547777': 2, 'NCT03919292': 0, 'NCT06894979': 0, 'NCT05256290': 0, 'NCT06161974': 1, 'NCT05168423': 2, 'NCT02800486': 1, 'NCT03896568': 1, 'NCT04590664': 4, 'NCT06072586': 2}
